# %%
# Internship Assignment for Pulling Data and Analysing Nifty 50 companies from NSE Website- Ajay Sir Quant

# %%
# Pulling data for Nifty companies

# %%
# Importing libraries
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup

# %%
# pulling nifty 50 companies from excel sheet. Excel sheet data dwonload from NSE website. 
data = pd.read_csv("nifty50list.csv") 
# To display first 5 items of the pandas dataframe
data.head()
# Out:
#                                  Company Name            Industry      Symbol  \
# 0  Adani Ports and Special Economic Zone Ltd.            SERVICES  ADANIPORTS
# 1                           Asian Paints Ltd.      CONSUMER GOODS  ASIANPAINT
# 2                              Axis Bank Ltd.  FINANCIAL SERVICES    AXISBANK
# 3                             Bajaj Auto Ltd.          AUTOMOBILE  BAJAJ-AUTO
# 4                          Bajaj Finance Ltd.  FINANCIAL SERVICES  BAJFINANCE
#
#   Series     ISIN Code
# 0     EQ  INE742F01042
# 1     EQ  INE021A01026
# 2     EQ  INE238A01034
# 3     EQ  INE917I01010
# 4     EQ  INE296A01024

# %%
# To display last 5 items of the pandas dataframe
data.tail()
# Out:
#              Company Name                  Industry      Symbol Series  \
# 45     Tech Mahindra Ltd.                        IT       TECHM     EQ
# 46     Titan Company Ltd.            CONSUMER GOODS       TITAN     EQ
# 47               UPL Ltd.  FERTILISERS & PESTICIDES         UPL     EQ
# 48  UltraTech Cement Ltd.  CEMENT & CEMENT PRODUCTS  ULTRACEMCO     EQ
# 49             Wipro Ltd.                        IT       WIPRO     EQ
#
#        ISIN Code
# 45  INE669C01036
# 46  INE280A01028
# 47  INE628A01036
# 48  INE481G01011
# 49  INE075A01022

# %%
# Dropping all the columns except Symbol
data = data.drop(["Company Name","Industry","Series","ISIN Code"], axis=1)
data
# Out:
#         Symbol
# 0   ADANIPORTS
# 1   ASIANPAINT
# 2     AXISBANK
# 3   BAJAJ-AUTO
# 4   BAJFINANCE
# 5   BAJAJFINSV
# 6         BPCL
# 7   BHARTIARTL
# 8    BRITANNIA
# 9        CIPLA
# 10   COALINDIA
# 11    DIVISLAB
# 12     DRREDDY
# 13   EICHERMOT
# 14      GRASIM
# 15     HCLTECH
# 16    HDFCBANK
# 17    HDFCLIFE
# 18  HEROMOTOCO
# 19    HINDALCO
# 20  HINDUNILVR
# 21        HDFC
# 22   ICICIBANK
# 23         ITC
# 24         IOC
# 25  INDUSINDBK
# 26        INFY
# 27    JSWSTEEL
# 28   KOTAKBANK
# 29          LT
# 30         M&M
# 31      MARUTI
# 32        NTPC
# 33   NESTLEIND
# 34        ONGC
# 35   POWERGRID
# 36    RELIANCE
# 37     SBILIFE
# 38    SHREECEM
# 39        SBIN
# 40   SUNPHARMA
# 41         TCS
# 42  TATACONSUM
# 43  TATAMOTORS
# 44   TATASTEEL
# 45       TECHM
# 46       TITAN
# 47         UPL
# 48  ULTRACEMCO
# 49       WIPRO

# %%
# Checking type of variable
print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# Changing data to a different variable
df= data
df
# Out:
#         Symbol
# 0   ADANIPORTS
# 1   ASIANPAINT
# 2     AXISBANK
# 3   BAJAJ-AUTO
# 4   BAJFINANCE
# 5   BAJAJFINSV
# 6         BPCL
# 7   BHARTIARTL
# 8    BRITANNIA
# 9        CIPLA
# 10   COALINDIA
# 11    DIVISLAB
# 12     DRREDDY
# 13   EICHERMOT
# 14      GRASIM
# 15     HCLTECH
# 16    HDFCBANK
# 17    HDFCLIFE
# 18  HEROMOTOCO
# 19    HINDALCO
# 20  HINDUNILVR
# 21        HDFC
# 22   ICICIBANK
# 23         ITC
# 24         IOC
# 25  INDUSINDBK
# 26        INFY
# 27    JSWSTEEL
# 28   KOTAKBANK
# 29          LT
# 30         M&M
# 31      MARUTI
# 32        NTPC
# 33   NESTLEIND
# 34        ONGC
# 35   POWERGRID
# 36    RELIANCE
# 37     SBILIFE
# 38    SHREECEM
# 39        SBIN
# 40   SUNPHARMA
# 41         TCS
# 42  TATACONSUM
# 43  TATAMOTORS
# 44   TATASTEEL
# 45       TECHM
# 46       TITAN
# 47         UPL
# 48  ULTRACEMCO
# 49       WIPRO

# %%
# Writing a code for pulling Last traded price, Total buy quantity and Total Sell quantity for the strategy

# %%
# Defining a function
#def stockcode():
stockcode ="TATAMOTORS"
print(stockcode)
stock_url  = 'https://www.nseindia.com/live_market/dynaContent/live_watch/get_quote/GetQuote.jsp?symbol='+str(stockcode)
print(stock_url)
headers = {'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.117 Safari/537.36'}
response = requests.get(stock_url, headers=headers)
response
soup = BeautifulSoup(response.text, 'html.parser')
data_array = soup.find(id='responseDiv').getText().strip().split(":")
type (data_array)
print(data_array)
# Extracting last traded Price
for item in data_array:
    if 'lastPrice' in item:
        index = data_array.index(item)+1
        print("Index -> "+ str(index))
        latestPrice=data_array[index].split('"')[1]
        print("latest Price = ",latestPrice)
                # Extracting Total buy Quantity
for item in data_array:
    if 'totalBuyQuantity' in item:
        index = data_array.index(item)+1
        print("Index -> "+ str(index))
        totalBuyQuantity=data_array[index].split('"')[1]
        print("totalBuyQuantity = ",totalBuyQuantity)
        # Extracting Total sell Quantity
for item in data_array:
     if 'totalSellQuantity' in item:
        index = data_array.index(item)+1
        print("Index -> "+ str(index))
        totalSellQuantity=data_array[index].split('"')[1]
        print("totalSellQuantity = ",totalSellQuantity)
# Out:
# TATAMOTORS
# https://www.nseindia.com/live_market/dynaContent/live_watch/get_quote/GetQuote.jsp?symbol=TATAMOTORS
# ...

# %%
# Write a For loop to repeat above codes for 50 stock
